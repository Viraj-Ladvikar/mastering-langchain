# %% [markdown]
# #### Invoke The model

# %%
import os 
from dotenv import load_dotenv
from langchain_groq import ChatGroq

os.environ['GROQ_API_KEY'] = os.getenv("GROQ_API_KEY")

llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0
)

# %% [markdown]
# ### Streaming And Batch
#
# ### Streaming
# Most models can stream their output content while it is being generated. By displaying output progressively, streaming significantly improves user experience, particularly for longer responses.
# Calling stream() returns an iterator that yields output chunks as they are produced. You can use a loop to process each chunk in real-time:

# %%
llm.invoke("Write me a 200 words paragraph on Artificial Intelligence")
# Out:
# AIMessage(content="Artificial Intelligence (AI) has revolutionized the way we live, work, and interact with technology. At its core, AI refers to the development of computer systems that can perform tasks that typically require human intelligence, such as learning, problem-solving, and decision-making. These systems use complex algorithms and machine learning techniques to analyze vast amounts of data, identify patterns, and make predictions or recommendations. From virtual assistants like Siri and Alexa to self-driving cars and personalized product recommendations, AI has become an integral part of our daily lives. As AI technology continues to advance, we can expect to see even more innovative applications, such as AI-powered healthcare diagnosis, autonomous farming, and intelligent transportation systems. However, the rapid growth of AI also raises important questions about its impact on employment, data privacy, and societal values. As we navigate the benefits and challenges of AI, it is essential to prioritize responsible development and deployment, ensuring that these powerful technologies serve humanity's best interests. By harnessing the potential of AI, we can create a brighter, more efficient, and more equitable future for all.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 218, 'prompt_tokens': 45, 'total_tokens': 263, 'completion_time': 0.268938028, 'completion_tokens_details': None, 'prompt_time': 0.002262317, 'prompt_tokens_details': None, 'queue_time': 0.158447747, 'total_time': 0.271200345}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_7ccc667439', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a0048d-9e52-7063-96eb-6225ea77175f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 45, 'output_tokens': 218, 'total_tokens': 263})

# %%
for chunk in llm.stream("Write me a 200 words paragraph on Artificial Intelligence"):
    print(chunk.content, end="", flush=True)
# Out:
# Artificial Intelligence (AI) has revolutionized the way we live, work, and interact with technology. At its core, AI refers to the development of computer systems that can perform tasks that typically require human intelligence, such as learning, problem-solving, and decision-making. These systems use complex algorithms and machine learning techniques to analyze vast amounts of data, identify patterns, and make predictions or recommendations. From virtual assistants like Siri and Alexa to self-driving cars and personalized product recommendations, AI has become an integral part of our daily lives. As AI technology continues to advance, we can expect to see even more innovative applications, such as AI-powered healthcare diagnosis, autonomous farming, and intelligent transportation systems. However, the rapid growth of AI also raises important questions about its impact on employment, data privacy, and societal values. As we navigate the benefits and challenges of AI, it is essential to prioritize responsible development and deployment, ensuring that these powerful technologies serve humanity's best interests. By harnessing the potential of AI, we can create a brighter, more efficient, and more equitable future for all.

# %% [markdown]
# #### Batch
# Batching a collection of independent requests to a model can significantly improve performance and reduce costs, as the processing can be done in parallel:

# %%
responses = llm.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
])

for response in responses:
    print(response)
# Out:
# content="Parrots have colorful feathers due to a combination of factors, primarily related to their evolution, behavior, and biology. Here are some reasons why parrots have such vibrant plumage:\n\n1. **Mating and courtship**: Bright colors are often associated with attractiveness and health in birds. Male parrots use their colorful feathers to attract females, showcase their fitness, and establish dominance. The more vibrant the colors, the more attractive the male is likely to be.\n2. **Communication**: Colorful feathers help parrots communicate with each other. Different colors can signal aggression, fear, or friendliness, allowing birds to convey complex information without vocalizations.\n3. **Camouflage and protection**: While it may seem counterintuitive, some parrots' colors can help them blend in with their surroundings. For example, the green plumage of some parrots helps them hide in foliage. However, this is not the primary reason for their colorful feathers.\n4. **Evolutionary pressures**: Parrots have evolved in a variety of environments, from tropical rainforests to savannas. In these environments, bright colors may have provided an advantage in terms of attracting mates, defending territory, or signaling dominance.\n5. **Pigmentation**: Parrots' colorful feathers are created by the presence of pigments, such as carotenoids (responsible for yellow, orange, and red colors) and melanins (responsible for black, brown, and gray colors). These pigments are produced by the bird's diet and metabolism.\n6. **Genetic variation**: Parrots have a high degree of genetic variation, which allows for the expression of different colors and patterns. This genetic diversity is thought to have contributed to the development of the wide range of colors seen in parrots.\n\nIn summary, parrots' colorful feathers are a result of a combination of factors, including mating and courtship, communication, camouflage, evolutionary pressures, pigmentation, and genetic variation." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 396, 'prompt_tokens': 43, 'total_tokens': 439, 'completion_time': 0.598889617, 'completion_tokens_details': None, 'prompt_time': 0.002540911, 'prompt_tokens_details': None, 'queue_time': 0.051688824, 'total_time': 0.601430528}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--01a0048f-341f-7d63-bbe5-0696aa3998ed-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 43, 'output_tokens': 396, 'total_tokens': 439}
# content="Airplanes fly by using the principles of aerodynamics, which is the study of the interaction between air and solid objects. The four main forces that act on an airplane in flight are:\n\n1. **Lift**: This is the upward force that opposes the weight of the airplane and keeps it flying. Lift is created by the shape of the wings, which are designed to produce a difference in air pressure above and below the wing. As the airplane moves forward, the air flows over and under the curved surface of the wing, creating an area of lower pressure above the wing and an area of higher pressure below it. This pressure difference creates an upward force called lift.\n2. **Weight**: This is the downward force that is equal to the weight of the airplane and its passengers.\n3. **Thrust**: This is the forward force that propels the airplane through the air. Thrust is created by the airplane's engines, which produce a stream of high-speed air that exits the back of the airplane.\n4. **Drag**: This is the backward force that opposes the motion of the airplane. Drag is created by air resistance, which slows down the airplane as it moves through the air.\n\nWhen an airplane is in flight, the four forces are in balance, with lift equal to weight and thrust equal to drag. This balance allows the airplane to fly steadily and maintain its altitude.\n\nHere's a step-by-step explanation of how an airplane flies:\n\n1. **Takeoff**: The airplane accelerates down the runway, gaining speed and lift.\n2. **Lift-off**: As the airplane reaches a certain speed, the lift generated by the wings becomes strong enough to counteract the weight of the airplane, and it lifts off the ground.\n3. **Climb**: The airplane continues to gain altitude, with the lift force increasing as the airspeed increases.\n4. **Cruise**: Once the airplane reaches its desired altitude, the engines produce a steady thrust that counteracts the drag force, allowing the airplane to fly steadily.\n5. **Descent**: As the airplane begins to descend, the lift force decreases, and the weight of the airplane becomes more dominant. The airplane slows down, and the engines produce less thrust to counteract the drag force.\n6. **Landing**: The airplane touches down on the runway, and the engines produce a reverse thrust to slow it down.\n\nIn summary, airplanes fly by using the principles of aerodynamics to create lift, which counteracts the weight of the airplane, and thrust, which propels the airplane through the air. The four forces of lift, weight, thrust, and drag are in balance, allowing the airplane to fly steadily and maintain its altitude." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 545, 'prompt_tokens': 40, 'total_tokens': 585, 'completion_time': 0.726542947, 'completion_tokens_details': None, 'prompt_time': 0.002773408, 'prompt_tokens_details': None, 'queue_time': 0.047962727, 'total_time': 0.729316355}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--01a0048f-3421-7dc2-b850-152c18be6d7e-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 40, 'output_tokens': 545, 'total_tokens': 585}
# content='Quantum computing is a new and rapidly evolving field of computer science that uses the principles of quantum mechanics to perform calculations and operations on data. Unlike classical computers, which use bits to store and process information, quantum computers use quantum bits or qubits.\n\n**Key principles of quantum computing:**\n\n1. **Superposition**: Qubits can exist in multiple states simultaneously, which allows for the processing of multiple possibilities at the same time.\n2. **Entanglement**: Qubits can be connected in a way that the state of one qubit is dependent on the state of the other, even if they are separated by large distances.\n3. **Quantum parallelism**: Quantum computers can perform many calculations simultaneously, thanks to the principles of superposition and entanglement.\n\n**How quantum computing works:**\n\n1. **Quantum gates**: Quantum computers use quantum gates, which are the quantum equivalent of logic gates in classical computers. Quantum gates perform operations on qubits, such as rotation, entanglement, and measurement.\n2. **Quantum algorithms**: Quantum algorithms are programs that run on quantum computers. They use quantum gates to perform calculations and operations on qubits.\n3. **Quantum measurement**: When a qubit is measured, its state collapses to one of the possible outcomes. This is known as wave function collapse.\n\n**Applications of quantum computing:**\n\n1. **Cryptography**: Quantum computers can break certain types of classical encryption, but they can also be used to create unbreakable quantum encryption.\n2. **Optimization**: Quantum computers can be used to solve complex optimization problems, such as the traveling salesman problem.\n3. **Simulation**: Quantum computers can simulate complex quantum systems, such as molecules and chemical reactions.\n4. **Machine learning**: Quantum computers can be used to speed up machine learning algorithms and improve their accuracy.\n\n**Challenges and limitations:**\n\n1. **Error correction**: Quantum computers are prone to errors due to the fragile nature of qubits. Developing robust error correction techniques is an active area of research.\n2. **Scalability**: Currently, quantum computers are small-scale and need to be scaled up to perform practical calculations.\n3. **Noise**: Quantum computers are sensitive to noise and interference, which can cause errors and affect the accuracy of calculations.\n\n**Current state of quantum computing:**\n\n1. **Quantum processors**: Several companies, such as IBM, Google, and Rigetti Computing, have developed quantum processors with a small number of qubits.\n2. **Quantum software**: Quantum software frameworks, such as Qiskit and Cirq, are being developed to program and run quantum algorithms.\n3. **Quantum applications**: Researchers are exploring various applications of quantum computing, including cryptography, optimization, and simulation.\n\nIn summary, quantum computing is a new and rapidly evolving field that uses the principles of quantum mechanics to perform calculations and operations on data. While there are many challenges and limitations, quantum computing has the potential to revolutionize various fields, from cryptography to machine learning.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 608, 'prompt_tokens': 40, 'total_tokens': 648, 'completion_time': 0.702443159, 'completion_tokens_details': None, 'prompt_time': 0.002731718, 'prompt_tokens_details': None, 'queue_time': 0.048569067, 'total_time': 0.705174877}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--01a0048f-3423-7ef1-92a4-948dd2f31235-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 40, 'output_tokens': 608, 'total_tokens': 648}

# %%
responses = llm.batch(
    [
        "Why do parrots have colorful feathers?",
        "How do airplanes fly?",
        "What is quantum computing?"
    ],
    config={
        "max_concurrency": 5
    }
)

responses
# Out:
# [AIMessage(content="Parrots have colorful feathers due to a combination of factors, primarily related to their evolution, behavior, and biology. Here are some reasons why parrots have such vibrant plumage:\n\n1. **Mating and courtship**: Bright colors are often associated with attractiveness and health in birds. Male parrots use their colorful feathers to attract females, showcase their fitness, and establish dominance. The more vibrant the colors, the more attractive the male is likely to be.\n2. **Communication**: Colorful feathers help parrots communicate with each other. Different colors can signal aggression, fear, or friendliness, allowing birds to convey complex information without vocalizations.\n3. **Camouflage and protection**: While it may seem counterintuitive, some parrots' colors can help them blend in with their surroundings. For example, the green plumage of some parrots helps them hide in foliage. However, this is not the primary reason for their colorful feathers.\n4. **Evolutionary pressures**: Parrots have evolved in a variety of environments, from tropical rainforests to savannas. In these environments, bright colors may have provided an advantage in terms of attracting mates, defending territory, or signaling dominance.\n5. **Pigmentation**: Parrots' colorful feathers are created by the presence of pigments, such as carotenoids (responsible for yellow, orange, and red colors) and melanins (responsible for black, brown, and gray colors). These pigments are produced by the bird's diet and metabolism.\n6. **Genetic variation**: Parrots have a high degree of genetic variation, which allows for the expression of different colors and patterns. This genetic diversity is thought to have contributed to the development of the wide range of colors seen in parrots.\n\nIn summary, parrots' colorful feathers are a result of a combination of factors, including mating and courtship, communication, camouflage, evolutionary pressures, pigmentation, and genetic variation.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 396, 'prompt_tokens': 43, 'total_tokens': 439, 'completion_time': 0.597452617, 'completion_tokens_details': None, 'prompt_time': 0.023560896, 'prompt_tokens_details': None, 'queue_time': 0.055346113, 'total_time': 0.621013513}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a00490-f980-7723-be87-442848dc4d36-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 396, 'total_tokens': 439}),
#  AIMessage(content='Airplanes fly by using the principles of aerodynamics, which is the study of the interaction between air and solid objects. The four main forces that act on an airplane in flight are:\n\n1. **Lift**: This is the upward force that opposes the weight of the airplane and keeps it flying. Lift is created by the shape of the wings, which are designed to produce a difference in air pressure above and below the wing. As the airplane moves forward, the air flows over and under the curved surface of the wing, creating an area of lower pressure above the wing and an area of higher pressure below it. This pressure difference creates an upward force called lift.\n\n2. **Weight**: This is the downward force that is equal to the weight of the airplane and its passengers. Weight is the force that the airplane\'s lift must counteract in order to keep it flying.\n\n3. **Thrust**: This is the forward force that propels the airplane through the air. Thrust is created by the airplane\'s engines, which produce a stream of high-speed air that exits the back of the airplane. This stream of air creates a forward force that propels the airplane forward.\n\n4. **Drag**: This is the backward force that opposes the motion of the airplane. Drag is created by the air resistance that the airplane encounters as it moves through the air.\n\nFor an airplane to fly, the lift must be greater than the weight, and the thrust must be greater than the drag. This is known as the "four forces of flight."\n\nHere\'s a step-by-step explanation of how an airplane flies:\n\n1. **Takeoff**: The airplane accelerates down the runway, building up speed and generating thrust.\n2. **Lift-off**: As the airplane reaches a certain speed, the wings begin to produce lift, and the airplane starts to rise into the air.\n3. **Climb**: The airplane continues to climb, with the lift force opposing the weight and the thrust force propelling it forward.\n4. **Cruise**: Once the airplane reaches a steady altitude, the lift and weight forces are balanced, and the airplane levels off.\n5. **Descent**: As the airplane begins to descend, the lift force decreases, and the weight force takes over, causing the airplane to lose altitude.\n6. **Landing**: The airplane touches down on the runway, and the thrust force is reduced to zero.\n\nIn summary, airplanes fly by using the principles of aerodynamics to create lift, thrust, and drag forces that work together to keep the airplane airborne.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 517, 'prompt_tokens': 40, 'total_tokens': 557, 'completion_time': 0.656320422, 'completion_tokens_details': None, 'prompt_time': 0.005730713, 'prompt_tokens_details': None, 'queue_time': 0.06610242, 'total_time': 0.662051135}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a00490-f982-7a53-8973-91f9d23c2461-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 517, 'total_tokens': 557}),
#  AIMessage(content='Quantum computing is a new and rapidly evolving field of computer science that uses the principles of quantum mechanics to perform calculations and operations on data. Unlike classical computers, which use bits to store and process information, quantum computers use quantum bits or qubits.\n\n**Key principles of quantum computing:**\n\n1. **Superposition**: Qubits can exist in multiple states simultaneously, which allows for the processing of multiple possibilities at the same time.\n2. **Entanglement**: Qubits can be connected in a way that the state of one qubit is dependent on the state of the other, even if they are separated by large distances.\n3. **Quantum parallelism**: Quantum computers can perform many calculations simultaneously, thanks to the principles of superposition and entanglement.\n\n**How quantum computing works:**\n\n1. **Quantum gates**: Quantum computers use quantum gates, which are the quantum equivalent of logic gates in classical computers. Quantum gates perform operations on qubits, such as rotation, entanglement, and measurement.\n2. **Quantum algorithms**: Quantum algorithms are programs that run on quantum computers. They use quantum gates to perform calculations and operations on qubits.\n3. **Quantum measurement**: When a qubit is measured, its state collapses to one of the possible outcomes. This is known as wave function collapse.\n\n**Applications of quantum computing:**\n\n1. **Cryptography**: Quantum computers can break certain types of classical encryption, but they can also be used to create unbreakable quantum encryption.\n2. **Optimization**: Quantum computers can be used to solve complex optimization problems, such as the traveling salesman problem.\n3. **Simulation**: Quantum computers can simulate complex quantum systems, such as molecules and chemical reactions.\n4. **Machine learning**: Quantum computers can be used to speed up machine learning algorithms and improve their accuracy.\n\n**Challenges and limitations:**\n\n1. **Error correction**: Quantum computers are prone to errors due to the fragile nature of qubits. Developing robust error correction techniques is an active area of research.\n2. **Scalability**: Currently, quantum computers are small-scale and need to be scaled up to perform practical calculations.\n3. **Noise**: Quantum computers are sensitive to noise and interference, which can cause errors and affect the accuracy of calculations.\n\n**Current state of quantum computing:**\n\n1. **Quantum processors**: Several companies, such as IBM, Google, and Rigetti Computing, have developed quantum processors with a small number of qubits.\n2. **Quantum software**: Quantum software frameworks, such as Qiskit and Cirq, are being developed to program and run quantum algorithms.\n3. **Quantum applications**: Researchers are exploring various applications of quantum computing, including cryptography, optimization, and simulation.\n\nIn summary, quantum computing is a new and rapidly evolving field that uses the principles of quantum mechanics to perform calculations and operations on data. While there are many challenges and limitations, quantum computing has the potential to revolutionize various fields, from cryptography to machine learning.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 608, 'prompt_tokens': 40, 'total_tokens': 648, 'completion_time': 0.686989697, 'completion_tokens_details': None, 'prompt_time': 0.0060653, 'prompt_tokens_details': None, 'queue_time': 0.065469293, 'total_time': 0.693054997}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a00490-f984-7710-a1d0-2df1e9d33372-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 608, 'total_tokens': 648})]
