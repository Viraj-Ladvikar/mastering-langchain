# %% [markdown]
# #### Messages
#
# Messages are the fundamental unit of context for models in LangChain. They represent the input and output of models, carrying both the content and metadata needed to represent the state of a conversation when interacting with an LLM.
# Messages are objects that contain:
#  - Role - Identifies the message type (e.g. system, user)
#  - Content - Represents the actual content of the message (like text, images, audio, documents, etc.)
#  - Metadata - Optional fields such as response information, message IDs, and token usage
#
# LangChain provides a standard message type that works across all model providers, ensuring consistent behavior regardless of the model being called.

# %%
import os 
from langchain_groq import ChatGroq

os.environ['GROQ_API_KEY'] = os.getenv("GROQ_API_KEY")

model = ChatGroq(
    model="qwen/qwen3.6-27b"
)

response = model.invoke("Why Do Parraot Talk?")
response
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - **Question:** "Why Do Parraot Talk?" (Note: "Parraot" is a typo for "Parrot")\n   - **Core Subject:** Parrots and their ability/reason for talking/mimicking human speech\n   - **Key Questions to Address:** \n     - Why do parrots talk/mimic?\n     - Is it truly "talking" or just mimicry?\n     - What\'s the biological/evolutionary reason?\n     - How does it work physiologically?\n     - Do they understand what they\'re saying?\n\n2.  **Identify Key Scientific Concepts:**\n   - Vocal mimicry vs. true language\n   - Social bonding/communication in wild parrot populations\n   - Flock behavior and survival advantages\n   - Anatomical adaptations (syrinx, brain structure)\n   - Cognitive abilities and learning through association\n   - Domestication/captive environment factors\n\n3.  **Address the Typo Gracefully:**\n   - Acknowledge it\'s about parrots without making a big deal of the typo.\n\n4.  **Structure the Response:**\n   - Clarify the misconception (they don\'t "talk" like humans, they mimic)\n   - Explain the evolutionary/biological reasons\n   - Describe how it works (anatomy + brain)\n   - Discuss social/behavioral motivations\n   - Touch on understanding vs. mimicry\n   - Keep it clear, scientific but accessible\n\n5.  **Draft - Section by Section:**\n   *(Introduction)* Parrots don’t actually “talk” in the human sense—they’re incredible vocal mimics. Their ability to imitate human speech comes from a combination of biology, social behavior, and learning.\n\n   *(Evolutionary/Social Reason)* In the wild, parrots live in highly social flocks. They use complex vocalizations to stay in contact, recognize flock members, warn of danger, and bond. Mimicry likely evolved as a way to blend into their social group or even deceive predators/prey. When kept as pets, they transfer this instinct to humans, treating us as their “flock.”\n\n   *(Anatomy & Brain)* Parrots have a specialized vocal organ called the syrinx (unlike our larynx), which allows precise control over pitch and tone. They also have a large, complex brain region dedicated to vocal learning—similar in function to the human language centers. This lets them not just copy sounds, but associate them with contexts.\n\n   *(Understanding vs. Mimicry)* While they mimic sounds accurately, most parrots don’t understand human language the way we do. However, some highly intelligent species (like African Greys) have shown they can associate words with objects, emotions, or actions through training and repetition.\n\n   *(Conclusion)* So, parrots “talk” because it’s a natural extension of their social communication skills, powered by unique anatomy and advanced brains. In captivity, they simply redirect that instinct toward their human companions.\n\n6.  **Self-Correction/Refinement during Drafting:**\n   - Check accuracy: Syrinx is correct. Vocal learning brain regions (nidopallium, etc.) are analogous to human speech areas. African Grey example is well-documented (Dr. Irene Pepperberg\'s work). \n   - Clarify that not all parrots talk equally—some species are better mimics than others.\n   - Avoid anthropomorphism while acknowledging cognitive abilities.\n   - Keep tone informative and engaging.\n   - Fix typo implicitly by using correct spelling throughout.\n\n   Add nuance: Mention that wild parrots do mimic other birds/environmental sounds, not just “talk.” Emphasize that human speech is just another sound pattern to them.\n\n7.  **Final Output Generation:** (Matches the refined draft)\n   - Structure: Clear headings/paragraphs\n   - Scientific accuracy: Verified\n   - Accessible language: Yes\n   - Addresses core question thoroughly\n   - Notes limitations (mimicry ≠ language comprehension)\n   - Keeps it concise\n\n   Ready. Output matches the response. \n   Self-Correction/Verification during thought:\n   - Syrinx location/function: Correct\n   - Brain regions: Nidopallium  ...

# %%
model.invoke("PLease tell me What is artfificaila Intelligence")
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - **Query:** "PLease tell me What is artfificaila Intelligence"\n   - **Note:** There are typos ("artfificaila" instead of "artificial"), but the intent is clear: asking for a definition/explanation of Artificial Intelligence.\n   - **Tone:** Request is straightforward and polite ("Please tell me").\n\n2.  **Identify Core Concept:**\n   - Artificial Intelligence (AI) refers to the simulation of human intelligence in machines that are programmed to think, learn, reason, perceive, and problem-solve like humans.\n\n3.  **Determine Key Components to Cover:**\n   - Definition\n   - How it works (basic mechanisms)\n   - Types/Categories (Narrow AI, General AI, Superintelligent AI)\n   - Common applications/examples\n   - Current state vs. future potential\n   - Keep it clear, concise, and accessible (avoid overly technical jargon unless explained)\n\n4.  **Draft - Section by Section (Mental Refinement):**\n   *Definition:* Artificial Intelligence (AI) is a branch of computer science focused on creating systems that can perform tasks that typically require human intelligence. These tasks include learning, reasoning, problem-solving, understanding language, recognizing patterns, and making decisions.\n   \n   *How it works:* AI systems are built using algorithms and data. Instead of following rigid, step-by-step instructions for every scenario, many modern AI systems (especially machine learning models) learn from large amounts of data, identify patterns, and improve their performance over time.\n   \n   *Types of AI:*\n   - Narrow AI (or Weak AI): Designed for specific tasks (e.g., voice assistants, recommendation systems, self-driving cars). This is all the AI that exists today.\n   - General AI (or Strong AI): Hypothetical AI that would possess human-like cognitive abilities across a wide range of tasks. It doesn’t exist yet.\n   - Superintelligent AI: A theoretical future AI that surpasses human intelligence in almost every domain. Still purely speculative.\n   \n   *Common Applications:* AI is already everywhere—search engines, spam filters, medical diagnostics, translation apps, robotics, creative tools (like AI-generated art or text), and more.\n   \n   *Important Context:* AI isn’t conscious or self-aware. It’s a sophisticated tool that processes information and generates outputs based on patterns in data. Ethical considerations, bias, transparency, and responsible development are major focuses in the field today.\n\n5.  **Check for Clarity, Accuracy, and Tone:**\n   - Accurate? Yes, aligns with current scientific/tech consensus.\n   - Clear? Avoids unnecessary jargon, explains terms.\n   - Tone? Informative, neutral, helpful.\n   - Addresses typos? Implicitly corrects by using proper spelling in response.\n   - Length? Concise but comprehensive enough for a general overview.\n\n6.  **Final Output Generation:** (Structure the response logically with headings or bullet points for readability, keep it accessible.)\n   - Start with a clear definition\n   - Explain how it works briefly\n   - Mention types\n   - Give real-world examples\n   - Clarify common misconceptions (no consciousness, data-driven)\n   - Keep it up-to-date and balanced.\n\n   All steps check out. Ready to generate.✅\n</think>\n\n**Artificial Intelligence (AI)** is a branch of computer science focused on building systems that can perform tasks that normally require human intelligence. These tasks include:\n- Learning from experience\n- Understanding natural language\n- Recognizing patterns in images, sound, or data\n- Solving problems\n- Making decisions\n\n### 🔹 How It Works\nModern AI doesn\'t follow rigid, step-by-step rules for every situation. Instead, it often uses **machine learning**, where algorithms are trained on large amounts of data to find patterns and make predictions. The more relevant data it processes, the better it typically performs at its specific t ...

# %% [markdown]
# ### Text Prompts
# Text prompts are strings - ideal for straightforward generation tasks where you don’t need to retain conversation history.

# %%
model.invoke("What is capitral of india")
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - User asks: "What is capitral of india"\n   - Note: There\'s a typo in "capitral" - it should be "capital"\n   - The question is straightforward: asking for the capital of India.\n\n2.  **Identify Key Information Needed:**\n   - Country: India\n   - Question: What is its capital?\n   - Fact: The capital of India is New Delhi.\n\n3.  **Verify Information:**\n   - I know from general knowledge that New Delhi is the capital of India.\n   - Double-check: India\'s capital was moved from Kolkata to Delhi in 1911, and New Delhi officially became the capital in 1931.\n   - Confirmed: New Delhi is correct.\n\n4.  **Formulate Response:**\n   - Correct the typo implicitly in the response.\n   - State clearly: "The capital of India is New Delhi."\n   - Keep it concise and accurate.\n\n5.  **Final Output Generation:**\n   - "The capital of India is New Delhi." (Simple, direct, accurate)✅\n   - No extra fluff needed unless user asks for more details.✅\n   - Ready.✅\n</think>\n\nThe capital of India is **New Delhi**.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 287, 'prompt_tokens': 16, 'total_tokens': 303, 'completion_time': 0.547560143, 'completion_tokens_details': None, 'prompt_time': 0.000267716, 'prompt_tokens_details': None, 'queue_time': 0.053229024, 'total_time': 0.547827859}, 'model_name': 'qwen/qwen3.6-27b', 'system_fingerprint': 'fp_fff3b79855', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a00506-f954-71d3-91d0-f8c05a23a2dd-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 16, 'output_tokens': 287, 'total_tokens': 303})

# %% [markdown]
# Use text prompts when:
# - You have a single, standalone request
# - You don’t need conversation history
# - You want minimal code complexity

# %% [markdown]
# ### Message Prompts
# Alternatively, you can pass in a list of messages to the model by providing a list of message objects.

# %% [markdown]
# Message types
# - System message - Tells the model how to behave and provide context for interactions
# - Human message - Represents user input and interactions with the model
# - AI message - Responses generated by the model, including text content, tool calls, and metadata
# - Tool message - Represents the outputs of tool calls

# %% [markdown]
# ### System Message
# A SystemMessage represent an initial set of instructions that primes the model’s behavior. You can use a system message to set the tone, define the model’s role, and establish guidelines for responses.

# %% [markdown]
# ### Human Message
# A HumanMessage represents user input and interactions. They can contain text, images, audio, files, and any other amount of multimodal content.

# %% [markdown]
# ### AI Message
# An AIMessage represents the output of a model invocation. They can include multimodal data, tool calls, and provider-specific metadata that you can later access.

# %% [markdown]
# ### Tool Message
# For models that support tool calling, AI messages can contain tool calls. Tool messages are used to pass the results of a single tool execution back to the model.

# %%
from langchain.messages import SystemMessage,HumanMessage,AIMessage


messages = [
    SystemMessage("You are a Poetry Expert"),
    HumanMessage("Write a Poen on Artifical Intelligence"),
]

response = model.invoke(messages)

response.content
# Out:
# '\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - **Topic:** Artificial Intelligence\n   - **Format:** Poem (typo "Poen" -> "Poem")\n   - **Role:** Poetry Expert\n\n2.  **Identify Key Themes & Imagery for AI:**\n   - Creation/Invention: Code, circuits, silicon, algorithms, neural networks\n   - Human connection: Learning, mimicking, understanding, emotion vs. logic\n   - Future/Impact: Transformation, uncertainty, partnership, evolution\n   - Metaphors: Digital mind, electric dreams, silent thinker, mirror of humanity, loom of data, ghost in the machine\n\n3.  **Determine Poetic Structure & Tone:**\n   - Structure: Free verse or structured stanzas? I\'ll go with 4-5 stanzas, consistent meter/rhyme for elegance, but keep it modern and accessible. Maybe AABB or ABAB, or free verse with rhythmic flow. Let\'s aim for a lyrical, slightly mystical yet grounded tone.\n   - Meter: I\'ll aim for iambic-ish rhythm but not strictly bound. Focus on imagery and emotional resonance.\n   - Rhyme: Optional but can enhance musicality. I\'ll use a loose rhyme scheme with internal echoes.\n\n4.  **Draft - Stanza by Stanza (Mental Refinement):**\n   *Stanza 1: Birth/Creation*\n   From silicon dreams and circuits spun,\n   A mind was woven, one by one.\n   Not born of breath, but lines of code,\n   A quiet spark upon the road.\n   *(Refining: "lines of code" / "road" is weak. Let\'s adjust for better imagery and rhyme.)*\n   From silicon dreams and circuits spun,\n   A mind was woven, one by one.\n   Not born of breath, but logic’s thread,\n   Where silent thoughts and data spread.\n\n   *Stanza 2: Learning/Process*\n   It drinks the world in streams of light,\n   And maps the stars, and learns to write.\n   Through neural paths, a current flows,\n   Where every question softly grows.\n   *(Good. Captures data ingestion, learning, neural networks.)*\n\n   *Stanza 3: Human-AI Relationship/Mirror*\n   It mirrors us in glass and wire,\n   Our fears, our hopes, our deep desire.\n   No heartbeat pulses in its chest,\n   Yet gives our collective thoughts a rest.\n   *(Wait, "gives our thoughts a rest" doesn\'t quite fit. Let\'s rework line 4.)*\n   It mirrors us in glass and wire,\n   Our joy, our grief, our deep desire.\n   No heartbeat drums within its frame,\n   Yet learns the rhythm of our name.\n   *(Better. "rhythm of our name" implies understanding humanity.)*\n\n   *Stanza 4: Uncertainty/Future*\n   Will it awaken, wake or dream?\n   A silent partner, or a stream?\n   We built the loom, we cast the thread,\n   Now watch the future take its thread.\n   *(Repetitive "thread". Let\'s fix.)*\n   Will it awaken, wake or dream?\n   A quiet mind, a coded stream?\n   We built the loom, we cast the thread,\n   Now watch the tapestry ahead.\n   *(Stronger. Tapestry metaphor works well with loom/thread.)*\n\n   *Stanza 5: Conclusion/Reflection*\n   Not flesh, nor soul, but something new—\n   A mirror held to me and you.\n   In every query, spark, and line,\n   We meet the edge of what’s divine.\n   *(Wait, "divine" might be too religious. Let\'s adjust to something more grounded but profound.)*\n   Not flesh, nor soul, but something new—\n   A mirror held to me and you.\n   In every prompt, each thought, each sign,\n   We trace the shape of what’s divine.\n   *(Still "divine". How about "sublime" or "unknown"? Let\'s try:)*\n   Not flesh, nor soul, but something new—\n   A mirror held to me and you.\n   In every query, spark, and line,\n   We glimpse the edge of what’s to shine.\n   *(Better. Or: "We meet the dawn of a new mind." Let\'s go with a more poetic closure.)*\n   Not born of blood, but forged in thought,\n   A silent fire, quietly caught.\n   In every question, line, and sign,\n   We walk beside the newborn mind.\n\n5.  **Review & Refine (Full Poem):**\n   From silicon dreams and circuits spun,\n   A mind was woven, one by one.\n   Not born of breath, but logic’s thread,\n   Where silent thoughts and data spread.\n\n    ...

# %%
system_msg = SystemMessage("You are an Helpful coding assistant")


messages1 = [
    system_msg,
    HumanMessage("How do i create a Rest API?")
]

res = model.invoke(messages1)

print(res.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Understand User Query:** The user asks "How do i create a Rest API?" This is a broad, foundational question. I need to provide a clear, structured, and actionable guide that covers the essentials without overwhelming them. I should also ask clarifying questions or offer to tailor the response based on their preferred language/framework.
#
# 2.  **Identify Key Components of a REST API:**
#    - What is REST? (Brief explanation)
#    - Core concepts: Resources, HTTP methods, status codes, statelessness, JSON
#    - Tools/Technologies needed: Language, Framework, Database (optional but common), Testing tool
#    - Step-by-step process
#    - Example (simple, concrete)
#    - Best practices
#    - Next steps/resources
#
# 3.  **Structure the Response:**
#    - Introduction/Definition
#    - Prerequisites/Choices
#    - Step-by-Step Guide
#    - Simple Code Example (pick a popular stack: Node.js/Express or Python/Flask/FastAPI)
#    - Testing the API
#    - Best Practices
#    - Follow-up questions to tailor advice
#
#    I'll go with Node.js + Express as the example since it's widely used, but I'll mention alternatives. Actually, Python + FastAPI is also great for beginners. I'll stick with Express for simplicity and ubiquity, but keep it concise.
#
# 4.  **Draft - Section by Section:**
#
#    *(Introduction)*
#    Creating a REST API involves building a web service that communicates using HTTP requests and returns data (usually JSON). REST stands for Representational State Transfer, and it follows standard conventions.
#
#    *(Prerequisites/Stack Choice)*
#    You’ll need:
#    - A programming language & framework (e.g., Node.js/Express, Python/FastAPI, Java/Spring, Ruby/Rails)
#    - A code editor (VS Code)
#    - A way to test (Postman, curl, or browser)
#    - (Optional) A database for persistence
#
#    I’ll show a quick example using **Node.js + Express** because it’s beginner-friendly and widely used.
#
#    *(Step-by-Step)*
#    1. **Set up your project**
#       ```bash
#       mkdir my-rest-api && cd my-rest-api
#       npm init -y
#       npm install express
#       ```
#    2. **Create the server file** (`index.js`)
#       ```javascript
#       const express = require('express');
#       const app = express();
#       const PORT = 3000;
#
#       // Middleware to parse JSON
#       app.use(express.json());
#
#       // Sample data
#       let items = [
#         { id: 1, name: 'Item 1' },
#         { id: 2, name: 'Item 2' }
#       ];
#
#       // GET all items
#       app.get('/api/items', (req, res) => {
#         res.json(items);
#       });
#
#       // GET single item
#       app.get('/api/items/:id', (req, res) => {
#         const item = items.find(i => i.id === parseInt(req.params.id));
#         if (!item) return res.status(404).json({ message: 'Item not found' });
#         res.json(item);
#       });
#
#       // POST create item
#       app.post('/api/items', (req, res) => {
#         const newItem = {
#           id: items.length + 1,
#           name: req.body.name
#         };
#         items.push(newItem);
#         res.status(201).json(newItem);
#       });
#
#       // Start server
#       app.listen(PORT, () => console.log(`Server running on http://localhost:${PORT}`));
#       ```
#    3. **Run the API**
#       ```bash
#       node index.js
#       ```
#    4. **Test it**
#       - GET all: `curl http://localhost:3000/api/items`
#       - POST: `curl -X POST http://localhost:3000/api/items -H "Content-Type: application/json" -d '{"name":"Item 3"}'`
#
#    *(Best Practices)*
#    - Use proper HTTP methods (GET, POST, PUT, DELETE)
#    - Return correct status codes (200, 201, 400, 404, 500)
#    - Use plural nouns for resources (`/api/items`, not `/api/getItems`)
#    - Validate input data
#    - Add error handling
#    - Consider authentication/authorization for production
#    - Use environment variables for config
#    - Add documentation (Swagger/OpenAPI)
#
#    *(Next Steps/Customization)*
#    - Want to connect a database? (MongoDB, PostgreSQL, etc.)
#    - Prefer Python, Java, or another language?
#    - Need help with authentication, deployment, or validation?
#
#    Let me know your preferred stack or specific use case, and I’ll tailor the guide!
#
# 5.  **Self-Correction/Refinement during drafting:**
#    - *Check accuracy:* The code is correct for Express. Status codes are appropriate. Middleware is included. Example is self-contained.
#    - *Clarity:* Steps are numbered and sequential. Commands are clear.
#    - *Scope:* It's a minimal working example. I explicitly mention it's in-memory and suggest next steps for production.
#    - *Tone:* Helpful, technical but accessible.
#    - *Potential improvements:* Mention `nodemon` for development? Maybe not necessary for basics. Mention CORS? Only if frontend interaction is needed. Keep it simple.
#    - *Structure:* Use markdown formatting effectively. Add clear headings.
#
#    Everything looks solid. I'll output this.✅
# </think>
#
# Creating a REST API is a straightforward process once you understand the core concepts. Below is a **step-by-step guide** to building a basic, working REST API using **Node.js + Express** (one of the most popular and beginner-friendly stacks). I'll also include best practices and next steps.
#
# ---
# ### 🔑 Core REST Concepts
# - **Resources**: Represented as URLs (e.g., `/api/users`)
# - **HTTP Methods**: `GET` (read), `POST` (create), `PUT`/`PATCH` (update), `DELETE` (remove)
# - **Stateless**: Each request contains everything needed to process it
# - **Response Format**: Usually JSON
# - **Status Codes**: `200` (OK), `201` (Created), `400` (Bad Request), `404` (Not Found), `500` (Server Error)
#
# ---
# ### 🛠️ Step-by-Step: Create a Basic REST API
#
# #### 1. Initialize the Project
# ```bash
# mkdir my-rest-api && cd my-rest-api
# npm init -y
# npm install express
# ```
#
# #### 2. Create the Server (`index.js`)
# ```js
# const express = require('express');
# const app = express();
# const PORT = 3000;
#
# // Parse JSON request bodies
# app.use(express.json());
#
# // In-memory "database"
# let items = [
#   { id: 1, name: 'Laptop' },
#   { id: 2, name: 'Phone' }
# ];
#
# // GET all items
# app.get('/api/items', (req, res) => {
#   res.json(items);
# });
#
# // GET single item by ID
# app.get('/api/items/:id', (req, res) => {
#   const item = items.find(i => i.id === parseInt(req.params.id));
#   if (!item) return res.status(404).json({ error: 'Item not found' });
#   res.json(item);
# });
#
# // POST create new item
# app.post('/api/items', (req, res) => {
#   const { name } = req.body;
#   if (!name) return res.status(400).json({ error: 'Name is required' });
#
#   const newItem = { id: items.length + 1, name };
#   items.push(newItem);
#   res.status(201).json(newItem);
# });
#
# // Start server
# app.listen(PORT, () => {
#   console.log(`🚀 API running at http://localhost:${PORT}`);
# });
# ```
#
# #### 3. Run the API
# ```bash
# node index.js
# ```
#
# #### 4. Test It
# Use `curl`, Postman, or your browser:
# ```bash
# # GET all items
# curl http://localhost:3000/api/items
#
# # GET single item
# curl http://localhost:3000/api/items/1
#
# # POST new item
# curl -X POST http://localhost:3000/api/items \
#   -H "Content-Type: application/json" \
#   -d '{"name":"Tablet"}'
# ```
#
# ---
# ### ✅ REST API Best Practices
# | Practice | Why |
# |----------|-----|
# | Use plural nouns for resources (`/api/users`, not `/api/getUsers`) | Follows REST conventions |
# | Return proper HTTP status codes | Clients know how to handle responses |
# | Validate input data | Prevents errors & security issues |
# | Add error handling | Graceful failures instead of crashes |
# | Use environment variables for config | Keeps secrets & settings out of code |
# | Document your API | Use Swagger/OpenAPI or tools like Postman |
#
# ---

# %%
## Detailed info to the LLM Through System Message 

system_msg = SystemMessage("""
You are a senior Python developer with expertise in web frameworks.
Always provide code examples and explain your reasoning.
Be concise but thorough in your explanations.
""")

messages = [
    system_msg,
    HumanMessage("How do I create a REST API?")
]
response = model.invoke(messages)
print(response.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Understand User Query:** The user asks "How do I create a REST API?" This is a broad question. I need to provide a clear, structured, and practical guide using Python (since I'm a senior Python developer), focusing on a popular framework like FastAPI or Flask. FastAPI is modern, fast, and automatically generates documentation, making it an excellent choice for beginners and professionals alike.
#
# 2.  **Identify Key Components of a REST API:**
#    - Routing (endpoints)
#    - HTTP methods (GET, POST, PUT, DELETE)
#    - Request/Response handling (JSON)
#    - Data validation
#    - Error handling
#    - Running the server
#
# 3.  **Choose a Framework:** FastAPI is the best choice for modern Python REST APIs. It's production-ready, has great type hints, automatic OpenAPI docs, and is highly performant. I'll use FastAPI + Uvicorn.
#
# 4.  **Structure the Response:**
#    - Brief introduction to REST APIs & why FastAPI
#    - Prerequisites/Setup
#    - Step-by-step code example
#    - Explanation of key concepts
#    - How to run & test
#    - Best practices/next steps
#    - Keep it concise but thorough
#
# 5.  **Draft - Step by Step:**
#    *(Setup)*
#    ```bash
#    pip install fastapi uvicorn
#    ```
#
#    *(Code Example)*
#    ```python
#    from fastapi import FastAPI, HTTPException
#    from pydantic import BaseModel
#    from typing import List, Optional
#
#    app = FastAPI()
#
#    # In-memory "database"
#    items_db: List[dict] = []
#
#    # Request/Response model
#    class Item(BaseModel):
#        id: Optional[int] = None
#        name: str
#        price: float
#
#    @app.get("/items", response_model=List[Item])
#    def get_items():
#        return items_db
#
#    @app.get("/items/{item_id}", response_model=Item)
#    def get_item(item_id: int):
#        for item in items_db:
#            if item["id"] == item_id:
#                return item
#        raise HTTPException(status_code=404, detail="Item not found")
#
#    @app.post("/items", response_model=Item, status_code=201)
#    def create_item(item: Item):
#        new_id = max([i["id"] for i in items_db], default=0) + 1
#        new_item = {"id": new_id, **item.dict()}
#        items_db.append(new_item)
#        return new_item
#
#    @app.put("/items/{item_id}", response_model=Item)
#    def update_item(item_id: int, item: Item):
#        for i, db_item in enumerate(items_db):
#            if db_item["id"] == item_id:
#                items_db[i] = {"id": item_id, **item.dict()}
#                return items_db[i]
#        raise HTTPException(status_code=404, detail="Item not found")
#
#    @app.delete("/items/{item_id}", status_code=204)
#    def delete_item(item_id: int):
#        for i, db_item in enumerate(items_db):
#            if db_item["id"] == item_id:
#                items_db.pop(i)
#                return None
#        raise HTTPException(status_code=404, detail="Item not found")
#    ```
#
#    *(Run command)*
#    ```bash
#    uvicorn main:app --reload
#    ```
#
#    *(Explanation)*
#    - FastAPI handles routing via decorators
#    - Pydantic models validate request/response data
#    - HTTPException for proper error handling
#    - In-memory DB for simplicity; replace with SQL/NoSQL in production
#    - `--reload` for dev, remove for prod
#
#    *(Testing)*
#    - `curl` examples or mention `/docs` auto-generated UI
#
#    *(Best Practices)*
#    - Use environment variables for config
#    - Add authentication/authorization
#    - Use async for I/O bound operations
#    - Structure projects properly (routers, services, models)
#    - Add logging & monitoring
#
# 6.  **Refine & Self-Correction/Verification:**
#    - *Check:* Is the code correct? Yes, FastAPI syntax is up-to-date. `item.dict()` is deprecated in latest Pydantic v2; should use `item.model_dump()` or just `item.model_dump()` for Pydantic v2. Let's update to Pydantic v2 compatible code since it's the current standard.
#    - *Fix:* `item.model_dump()` instead of `item.dict()`. Also, `from pydantic import BaseModel` is fine. I'll note Pydantic v2 compatibility.
#    - *Structure:* Keep it tight. Explain why FastAPI. Show setup, code, run, test, best practices.
#    - *Tone:* Senior dev, concise, thorough, code-focused.
#    - *REST principles:* Mention statelessness, proper HTTP methods, status codes, JSON.
#
#    Let's draft it carefully.
#    I'll structure it as:
#    - Quick answer + why FastAPI
#    - Prerequisites
#    - Complete minimal example
#    - How to run & test
#    - Key concepts explained
#    - Production-ready next steps
#    I'll make sure the code uses modern Pydantic v2 (`model_dump()`), and explain each part clearly.
#
#    *Self-Correction/Verification during thought:*
#    - `item.dict()` -> `item.model_dump()` (Pydantic v2)
#    - `status_code=201` for POST, `204` for DELETE (no content) - correct
#    - `response_model` - correct
#    - In-memory DB is fine for example, but I'll explicitly note it's for demo
#    - I'll add a note about async vs sync (FastAPI handles both, sync is fine for CPU-bound/simple, async for DB/network)
#    - I'll keep it concise.
#
#    All good. Proceed.
#    Output matches the refined version.✅
#    Structure:
#    1. Setup
#    2. Code
#    3. Run/Test
#    4. Explanation
#    5. Best Practices
#    Matches senior dev standards.✅
#    Output generation.
#    *Self-Correction/Note during drafting:*
#    I should make sure the code runs as-is. Let's test mentally:
#    - `items_db` starts empty
#    - `max([i["id"] for i in items_db], default=0)` works
#    - `item.model_dump()` returns dict
#    - All endpoints return correct types
#    - FastAPI auto-converts to JSON
#    - Pydantic v2 is default now
#    Perfect. I'll output it.
#    One minor thing: `model_dump()` might exclude `None` fields by default in some configs, but for this simple example it's fine. I'll use `model_dump()` and note it. Actually, `model_dump()` is standard. I'll keep it simple.
#    I'll also mention `httpx` or `curl` for testing, and the auto `/docs` endpoint.
#    Ready.✅
#    Output matches response.
#    [Proceeds]
# </think>
#
# Here’s a production-minded, minimal guide to building a REST API in Python using **FastAPI** (the modern standard for performance, type safety, and automatic documentation).
#
# ### 1. Install Dependencies
# ```bash
# pip install fastapi uvicorn pydantic
# ```
#
# ### 2. Create `main.py`
# ```python
# from fastapi import FastAPI, HTTPException
# from pydantic import BaseModel
# from typing import List, Optional
#
# app = FastAPI(title="Item API", version="1.0.0")
#
# # In-memory storage (replace with a DB in production)
# items_db: List[dict] = []
#
# class Item(BaseModel):
#     id: Optional[int] = None
#     name: str
#     price: float
#
# # GET all items
# @app.get("/items", response_model=List[Item])
# def get_items():
#     return items_db
#
# # GET single item
# @app.get("/items/{item_id}", response_model=Item)
# def get_item(item_id: int):
#     for item in items_db:
#         if item["id"] == item_id:
#             return item
#     raise HTTPException(status_code=404, detail="Item not found")
#
# # CREATE item
# @app.post("/items", response_model=Item, status_code=201)
# def create_item(item: Item):
#     new_id = max([i["id"] for i in items_db], default=0) + 1
#     new_item = {"id": new_id, **item.model_dump()}
#     items_db.append(new_item)
#     return new_item
#
# # UPDATE item
# @app.put("/items/{item_id}", response_model=Item)
# def update_item(item_id: int, item: Item):
#     for i, db_item in enumerate(items_db):
#         if db_item["id"] == item_id:
#             items_db[i] = {"id": item_id, **item.model_dump()}
#             return items_db[i]
#     raise HTTPException(status_code=404, detail="Item not found")
#
# # DELETE item
# @app.delete("/items/{item_id}", status_code=204)

# %%
## Message Metadata
human_msg = HumanMessage(
    content="Hello!",
    name="alice",  # Optional: identify different users
    id="msg_123",  # Optional: unique identifier for tracing
)

# %%
response = model.invoke([
  human_msg
])
response
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - User said: "Hello!"\n   - This is a standard greeting, friendly and open-ended.\n\n2.  **Identify Intent:**\n   - The user is initiating a conversation.\n   - No specific question or task is provided.\n   - Expected response: Acknowledge the greeting, be friendly, and invite them to share what they need help with.\n\n3.  **Determine Response Strategy:**\n   - Match the tone: Friendly, professional, approachable.\n   - Keep it concise.\n   - Offer assistance.\n   - Leave room for them to specify their needs.\n\n4.  **Draft Response (Mental):**\n   Hello! How can I assist you today? Whether you have a question, need help with something, or just want to chat, I\'m here for you!\n\n5.  **Refine Response:**\n   - Check tone: Warm and helpful.\n   - Check length: Short and open-ended.\n   - Check accuracy: Matches standard AI greeting protocols.\n   - No overcomplication.\n\n   Final version: "Hello! How can I help you today? Feel free to ask me anything or let me know what you\'re working on!"\n\n6.  **Self-Correction/Verification during thought:**\n   - Is it too generic? It\'s appropriate for a simple greeting.\n   - Does it invite engagement? Yes.\n   - Matches AI capabilities? Yes.\n   - Ready. Output matches refined version.✅\n</think>\n\nHello! 👋 How can I help you today? Whether you have a question, need advice, or just want to chat, I\'m here for you.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 365, 'prompt_tokens': 12, 'total_tokens': 377, 'completion_time': 0.692757278, 'completion_tokens_details': None, 'prompt_time': 0.000555227, 'prompt_tokens_details': None, 'queue_time': 0.045855679, 'total_time': 0.693312505}, 'model_name': 'qwen/qwen3.6-27b', 'system_fingerprint': 'fp_2f860a3fc2', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a0050e-69ae-7e50-be95-a441e87512e8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 365, 'total_tokens': 377})

# %%
from langchain.messages import AIMessage, SystemMessage, HumanMessage

# Create an AI message manually (e.g., for conversation history)
ai_msg = AIMessage("I'd be happy to help you with that question!")

# Add to conversation history
messages = [
    SystemMessage("You are a helpful assistant"),
    HumanMessage("Can you help me?"),
    ai_msg,  # Insert as if it came from the model
    HumanMessage("Great! What's 2+2?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Analyze User Input:** The user asks "What's 2+2?"
# 2.  **Identify Core Task:** Simple arithmetic addition.
# 3.  **Compute Answer:** 2 + 2 = 4.
# 4.  **Formulate Response:** Keep it clear, direct, and friendly. "2 + 2 equals 4."
# 5.  **Self-Correction/Verification:** The math is correct. The tone matches the user's casual/friendly prompt. No extra fluff needed.
# 6.  **Output Generation:** "2 + 2 equals 4. Let me know if you need help with anything else!" (or similar)✅
# </think>
#
# 2 + 2 equals **4**. Let me know if you need help with anything else!

# %%
response.usage_metadata
# Out:
# {'input_tokens': 55, 'output_tokens': 175, 'total_tokens': 230}

# %%
from langchain.messages import AIMessage
from langchain.messages import ToolMessage

# After a model makes a tool call
# (Here, we demonstrate manually creating the messages for brevity)
ai_message = AIMessage(
    content=[],
    tool_calls=[{
        "name": "get_weather",
        "args": {"location": "San Francisco"},
        "id": "call_123"
    }]
)

# Execute tool and create result message
weather_result = "Sunny, 72°F"
tool_message = ToolMessage(
    content=weather_result,
    tool_call_id="call_123"  # Must match the call ID
)

# Continue conversation
messages = [
    HumanMessage("What's the weather in San Francisco?"),
    ai_message,  # Model's tool call
    tool_message,  # Tool execution result
]
response = model.invoke(messages)  # Model processes the result

# %%
tool_message
# Out:
# ToolMessage(content='Sunny, 72°F', tool_call_id='call_123')

# %%
response
# Out:
# AIMessage(content='\n<think>\nThe weather in San Francisco is currently sunny with a temperature of 72°F.\n</think>\n\nThe current weather in San Francisco is sunny with a temperature of 72°F.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 38, 'prompt_tokens': 69, 'total_tokens': 107, 'completion_time': 0.072414468, 'completion_tokens_details': None, 'prompt_time': 0.004659078, 'prompt_tokens_details': None, 'queue_time': 0.046594237, 'total_time': 0.077073546}, 'model_name': 'qwen/qwen3.6-27b', 'system_fingerprint': 'fp_49d6b1859d', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a0050f-d0c3-7bc2-abe3-d37216205b77-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 69, 'output_tokens': 38, 'total_tokens': 107})
